# %%
import pandas as pd

# %%
df = pd.read_csv('stationlist.csv')
df
# Out:
#           Station    Latitude    Longitude                       geometry
# 0      1001099999  70٫9333333   -8٫6666667  POINT (-8.6666667 70.9333333)
# 1      1001499999   59٫791925      5٫34085      POINT (5.34085 59.791925)
# 2     10018099999    54٫91325     8٫340472      POINT (8.340472 54.91325)
# 3      1003099999          77         15٫5                POINT (15.5 77)
# 4     10033099999  54٫8333333          9٫5         POINT (9.5 54.8333333)
# ...           ...         ...          ...                            ...
# 5352  98751099999        8٫15  125٫1333333       POINT (125.1333333 8.15)
# 5353  98752099999        8٫95  125٫4833333       POINT (125.4833333 8.95)
# 5354  98753099999    7٫125522   125٫645778    POINT (125.645778 7.125522)
# 5355  98755099999   8٫3666666  126٫3333333  POINT (126.3333333 8.3666666)
# 5356  98836099999    6٫922419   122٫059633    POINT (122.059633 6.922419)
#
# [5357 rows x 4 columns]

# %%
stationList = df['Station'].tolist()
stationList
# Out:
# [1001099999,
#  1001499999,
#  10018099999,
#  1003099999,
#  10033099999,
#  10037099999,
#  10038099999,
#  10046599999,
#  1007099999,
#  1008099999,
#  1010099999,
#  10126099999,
#  10136099999,
#  10149099999,
#  1015099999,
#  10162499999,
#  10172099999,
#  10193599999,
#  1023099999,
#  10246099999,
#  1025099999,
#  1026099999,
#  1028099999,
#  10304099999,
#  10321099999,
#  1033099999,
#  10334099999,
#  10335099999,
#  10343099999,
#  10416099999,
#  10426099999,
#  10436099999,
#  10437499999,
#  10439099999,
#  1046099999,
#  1047099999,
#  10476099999,
#  1049099999,
#  10500099999,
#  10502099999,
#  1052099999,
#  1055099999,
#  10553699999,
#  1059099999,
#  10607099999,
#  10613099999,
#  10614099999,
#  10616099999,
#  1062099999,
#  10633099999,
#  1068099999,
#  10687099999,
#  10727599999,
#  1074099999,
#  10743099999,
#  10752099999,
#  10755099999,
#  10775099999,
#  1078099999,
#  10805099999,
#  1083099999,
#  10837099999,
#  10853099999,
# ...
